# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('train_data.xlsx')

# %%
df.head()
# Out:
#    Statistics(out of 400)  Programming(out of 200)  \
# 0                     337                      118
# 1                     324                      107
# 2                     316                      104
# 3                     322                      110
# 4                     314                      103
#
#    Candidate's_UG_Rating(out of 5)  Work_experience(in years)  \
# 0                                4                        4.5
# 1                                4                        4.0
# 2                                3                        3.0
# 3                                3                        3.5
# 4                                2                        2.0
#
#    CV_Strength(out of 5)  UG_GPA(Scale of 10)  Published_Papers  \
# 0                    4.5                 9.65                 1
# 1                    4.5                 8.87                 1
# 2                    3.5                 8.00                 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Statistics(out of 400)                       500 non-null    int64
#  1   Programming(out of 200)                      500 non-null    int64
#  2   Candidate's_UG_Rating(out of 5)              500 non-null    int64
#  3   Work_experience(in years)                    500 non-null    float64
#  4   CV_Strength(out of 5)                        500 non-null    float64
#  5   UG_GPA(Scale of 10)                          500 non-null    float64
#  6   Published_Papers                             500 non-null    int64
#  7   Possibility_of_admission(range from 0 to 1)  500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
df.describe()
# Out:
#        Statistics(out of 400)  Programming(out of 200)  \
# count              500.000000               500.000000
# mean               316.472000               107.192000
# std                 11.295148                 6.081868
# min                290.000000                92.000000
# 25%                308.000000               103.000000
# 50%                317.000000               107.000000
# 75%                325.000000               112.000000
# max                340.000000               120.000000
#
#        Candidate's_UG_Rating(out of 5)  Work_experience(in years)  \
# count                       500.000000                 500.000000
# mean                          3.114000                   3.374000
# std                           1.143512                   0.991004
# min                           1.000000                   1.000000
# 25%                           2.000000                   2.500000
# 50%                           3.000000                   3.500000
# ...

# %%
df.isnull().mean()
# Out:
# Statistics(out of 400)                         0.0
# Programming(out of 200)                        0.0
# Candidate's_UG_Rating(out of 5)                0.0
# Work_experience(in years)                      0.0
# CV_Strength(out of 5)                          0.0
# UG_GPA(Scale of 10)                            0.0
# Published_Papers                               0.0
# Possibility_of_admission(range from 0 to 1)    0.0
# dtype: float64

# %%
X = df.drop(['Possibility_of_admission(range from 0 to 1)'], axis =1)
y = df['Possibility_of_admission(range from 0 to 1)']

# %%
sns.heatmap(X.corr(),cbar=True,annot=True)

# %%
#2:1
#6:1
#6:2

# %%
X
# Out:
#      Statistics(out of 400)  Programming(out of 200)  \
# 0                       337                      118
# 1                       324                      107
# 2                       316                      104
# 3                       322                      110
# 4                       314                      103
# ..                      ...                      ...
# 495                     332                      108
# 496                     337                      117
# 497                     330                      120
# 498                     312                      103
# 499                     327                      113
#
#      Candidate's_UG_Rating(out of 5)  Work_experience(in years)  \
# 0                                  4                        4.5
# 1                                  4                        4.0
# 2                                  3                        3.0
# 3                                  3                        3.5
# ...

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Possibility_of_admission(range from 0 to 1), Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test =- scaler.transform(X_test)

# %%
import keras 
from keras.models import Sequential 
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(10, kernel_initializer='random_uniform', activation= "relu", input_dim =7))
model.add(Dense(5, kernel_initializer='random_uniform', activation="relu"))
model.add(Dense(10, kernel_initializer='random_uniform', activation="relu"))

model.add(Dense(1, kernel_initializer='random_uniform', activation="sigmoid"))
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X_train, y_train, batch_size=10, epochs=100)
# Out:
# WARNING:tensorflow:From C:\Users\chuda\anaconda3\envs\Rushabh\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\chuda\anaconda3\envs\Rushabh\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\chuda\anaconda3\envs\Rushabh\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# ...

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[0.77159023],
#        [0.61120707],
#        [0.6612332 ],
#        [0.56969756],
#        [0.8494871 ],
#        [0.81621313],
#        [0.92568564],
#        [0.76830757],
#        [0.9347801 ],
#        [0.7161354 ],
#        [0.86117077],
#        [0.7369131 ],
#        [0.86124486],
#        [0.70654404],
#        [0.5682664 ],
#        [0.9325409 ],
#        [0.6105696 ],
#        [0.8388181 ],
#        [0.6899836 ],
#        [0.9304066 ],
#        [0.92936325],
#        [0.7052271 ],
#        [0.9315922 ],
#        [0.53113294],
#        [0.624387  ],
#        [0.7384473 ],
#        [0.7385205 ],
#        [0.93959594],
#        [0.885947  ],
#        [0.88240755],
#        [0.7766079 ],
#        [0.9384136 ],
#        [0.8161677 ],
#        [0.6077272 ],
#        [0.8956611 ],
#        [0.8450136 ],
#        [0.5966072 ],
#        [0.5619438 ],
#        [0.8683985 ],
#        [0.8238894 ],
#        [0.8164036 ],
#        [0.5392026 ],
#        [0.5678443 ],
# ...

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 0.06798589571078902

# %%
test_df = pd.read_excel("test_data (1).xlsx")

# %%
td = test_df[X.columns]

# %%
td.head()
# Out:
#    Statistics(out of 400)  Programming(out of 200)  \
# 0                     299                      100
# 1                     321                      112
# 2                     322                      112
# 3                     334                      119
# 4                     325                      114
#
#    Candidate's_UG_Rating(out of 5)  Work_experience(in years)  \
# 0                                3                        2.0
# 1                                3                        3.0
# 2                                4                        3.5
# 3                                5                        4.5
# 4                                5                        4.0
#
#    CV_Strength(out of 5)  UG_GPA(Scale of 10)  Published_Papers
# 0                    3.0                 7.42                 0
# 1                    4.5                 8.95                 1
# 2                    2.5                 9.02                 1
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X = sc.fit_transform(X)
td = sc.transform(td)

# %%
model = Sequential()
model.add(Dense(10, kernel_initializer='random_uniform', activation= "relu", input_dim =7))
model.add(Dense(5, kernel_initializer='random_uniform', activation="relu"))
model.add(Dense(10, kernel_initializer='random_uniform', activation="relu"))

model.add(Dense(1, kernel_initializer='random_uniform', activation="sigmoid"))
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 400/400 [==============================] - 0s 729us/step - loss: 0.6873 - accuracy: 0.0000e+00
# Epoch 2/100
# 400/400 [==============================] - 0s 194us/step - loss: 0.6619 - accuracy: 0.0000e+00
# Epoch 3/100
# 400/400 [==============================] - 0s 198us/step - loss: 0.5912 - accuracy: 0.0000e+00
# Epoch 4/100
# 400/400 [==============================] - 0s 202us/step - loss: 0.5480 - accuracy: 0.0000e+00
# Epoch 5/100
# 400/400 [==============================] - 0s 200us/step - loss: 0.5462 - accuracy: 0.0000e+00
# Epoch 6/100
# 400/400 [==============================] - 0s 200us/step - loss: 0.5458 - accuracy: 0.0000e+00
# Epoch 7/100
# 400/400 [==============================] - 0s 202us/step - loss: 0.5455 - accuracy: 0.0000e+00
# Epoch 8/100
# 400/400 [==============================] - 0s 199us/step - loss: 0.5451 - accuracy: 0.0000e+00
# Epoch 9/100
# 400/400 [==============================] - 0s 200us/step - loss: 0.5448 - accuracy: 0.0000e+00
# ...

# %%
pred = model.predict(td)

# %%
pred
# Out:
# array([[0.48411953],
#        [0.8212829 ],
#        [0.8226628 ],
#        [0.9422809 ],
#        [0.9141315 ],
#        [0.92547786],
#        [0.71897656],
#        [0.7536572 ],
#        [0.7368635 ],
#        [0.91763306],
#        [0.6670282 ],
#        [0.76381356],
#        [0.86981225],
#        [0.7624973 ],
#        [0.6130079 ],
#        [0.5873152 ],
#        [0.58665687],
#        [0.62558794],
#        [0.7256839 ],
#        [0.6820767 ],
#        [0.5423988 ],
#        [0.7878078 ],
#        [0.9160385 ],
#        [0.8830781 ],
#        [0.8964008 ],
#        [0.9028623 ],
#        [0.9306159 ],
#        [0.8170236 ],
#        [0.7671289 ],
#        [0.76708186],
#        [0.8259357 ],
#        [0.88102126],
#        [0.9134011 ],
#        [0.75014174],
#        [0.6209266 ],
#        [0.54078436],
#        [0.5430582 ],
#        [0.49223107],
#        [0.67649233],
#        [0.88899267],
#        [0.7821638 ],
#        [0.602189  ],
#        [0.58233255],
# ...

# %%
pred = pd.DataFrame(pred)

# %%
pred.to_csv('Attempt1.csv')
